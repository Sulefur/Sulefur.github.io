# %% [markdown]
# # Титульный лист

# %% [markdown]
# <font face="times new roman" size="3" color="black">
# <center> МИНИСТЕРСТВО ЦИФРОВОГО РАЗВИТИЯ, СВЯЗИ И МАССОВЫХ КОММУНИКАЦИЙ РОССИЙСКОЙ ФЕДЕРАЦИИ </center>
# <center>Ордена Трудового Красного Знамени федеральное государственное бюджетное образовательное учреждение высшего образования </center>
# <center> <strong> «Московский технический университет связи и информатики» </strong> </center>
#
#   <hr>
# <center> Кафедра «Телевидения и звукового вещания им. С.И. Катаева (ТиЗВ)» </center>
# <br>
# <center> <font face="times new roman" size="3" color="black"> Отчет по лабораторной работе №6 </center>
# <center>по дисциплине </center>
# <center><b>«Информационные технологии и программирование»</b></center>
# <center>на тему</center>
# <center><b>«Начало работы с Web-ом»</b> </center>
#
# </font>
#
#   <br><br><br><br><br>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Выполнил: студент группы </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black">       БИК2302 </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Андреечева Ксения Андреевна</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Проверил:</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Ассистент кафедры ТиЗВ Кудряшов Всеволод Владимирович </p>
#   <br>
#   <br>
#
#   <p  align="center"> <font face="times new roman" size="2" color="black"> Москва, 2023 г. </p>
#
#   <hr>

# %% [markdown]
# > ## Содержание

# %% [markdown]
# [1. Титульный лист](#Титульный_лист)
#
# <a href = '#Постановка_задач'>2. Постановка задач </a>

# %% [markdown]
# # Постановка задач
# <a name = 'Постановка_задач'>

# %% [markdown]
# > ## Задание

# %% [markdown]
# ##Цель работы

# %% [markdown]
# <strong>1.</strong> Изучение языка <strong>HTML</strong>
#
# <strong>2.</strong> Создание веб-сайта

# %% [markdown]
# ##Цель работы

# %% [markdown]
# ##Задачи работы
#
# 1. Изучить материалы для выполнения работы
# 2. Установить среду Visual Studio Code и плагин для проверки результата отображения HTML файла в браузере
#
# 3. Подготовьте 4 html страницы – 1-я главная (index) и 3 дочерних
# 4. Создать директории для хранения фото, видео, музыки, скриптов и таблиц стилей
# 5. Создать на главной странице Заголовок, Описание, Ссылки на все дочерние страницы
# 6. Добавить медиафайлы на дочерние страницы и иконку сайта
# 7. Создать таблицу стилей CSS и подключить её к созданным страницам

# %% [markdown]
# # Ход работы
# <a name = 'Ход работы'>

# %% [markdown]
# 1. Решение задачи 1.
#
# Я ознакомилась с предоставленными материалами для выполнения практической работы.

# %% [markdown]
# 2. Решение задачи 2.
#
# Я установила среду Visual Studio Code и плагин Live Preview.

# %% [markdown]
# ![Снимок экрана (26).png](data:image/png;base64,...)

# %% [markdown]
# 3. Решение задачи 3.
#
# Я подготовила 4 страницы html(1-ая главная и 3 дочерних).

# %% [markdown]
# 4. Решение задачи 4.
#
# Я создала директории для хранения фото, музыки, видео, скриптов и таблиц стилей.

# %% [markdown]
# 5. Решение задачи 5.
#
# Создала на главной странице Заголовок, Описание, Ссылки на все дочерние страницы.

# %% [markdown]
# 6. Решение задачи 6.
#
# На первую дочернюю страницу я добавила фото, на вторую - звуковую дорожку, на третью добавила - видеофайл. Также добавила иконку сайта.

# %% [markdown]
# ![photo_2023-10-20_23-18-52.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![photo_2023-10-20_23-36-01.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![photo_2023-10-20_23-26-51.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![photo_2023-10-20_23-40-18.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 7. Решение задачи 7.
#
# Я создала таблицу стилей CSS и подключила ее к созданным страницам.

# %% [markdown]
# # Итог работы
# <a name = 'Итог работы'>

# %% [markdown]
# Я научилась пользоваться языком <strong>HTML</strong>, в результате чего смогла создать веб-сайт.
